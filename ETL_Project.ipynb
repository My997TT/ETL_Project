# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
#import psycopg2

# %%
#Read files and create df from "Happy Planet Index 2016" (Countries Grouped by region)
h_path= "hpi-data-2016.xlsx"
h_read = pd.DataFrame(pd.read_excel(h_path, sheet_name='Complete HPI data',skiprows=5,skip_footer=17))
h_read= h_read.drop('Unnamed: 0', axis=1)
Country_indicators = pd.DataFrame(h_read)
# Out:
# C:\Users\my997\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: the 'skip_footer' keyword is deprecated, use 'skipfooter' instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
Country_indicators.rename(columns={
                                'HPI Rank':'HPI_Rank',
                                'Average Life \nExpectancy':'Average_Life_Expectancy',
                                'Average Wellbeing\n(0-10)':'Average_Wellbeing',
                                'Happy Life Years':'Happy_Life_Years',
                                'Footprint\n(gha/capita)':'Footprint_gha_Pcapita',
                                'Inequality of Outcomes':'Inequality_of_Outcomes',
                                'Inequality-adjusted Life Expectancy':'Inequality-adjusted_Life_Expectancy',
                                'Inequality-adjusted Wellbeing':'Inequality-adjusted_Wellbeing',
                                'Happy Planet Index':'Happy_Planet_Index',
                                'GDP/capita\n($PPP)':'GDP_Pcapita',
                                'GINI index':'GINI_index'
                                }, inplace=True)

Country_indicators
# Out:
#      HPI_Rank      Country                        Region  \
# 0         110  Afghanistan  Middle East and North Africa
# 1          13      Albania                Post-communist
# 2          30      Algeria  Middle East and North Africa
# 3          19    Argentina                      Americas
# 4          73      Armenia                Post-communist
# ..        ...          ...                           ...
# 135        29    Venezuela                      Americas
# 136         5      Vietnam                  Asia Pacific
# 137        94        Yemen  Middle East and North Africa
# 138        77       Zambia            Sub Saharan Africa
# 139        99     Zimbabwe            Sub Saharan Africa
#
#      Average_Life_Expectancy  Average_Wellbeing  Happy_Life_Years  \
# 0                     59.668                3.8         12.396024
# 1                     77.347                5.5         34.414736
# 2                     74.313                5.6         30.469461
# ...

# %%
#Read files and create df from "Data Source World Development Indicators" (All arrival of travellers by Country by Year)
t_path= "API_ST.INT.ARVL_DS2_en_csv_v2_823405.csv"
t_read = pd.read_csv(t_path, delimiter=',',skiprows=4)
t_read
# Out:
#      Country Name Country Code                             Indicator Name  \
# 0           Aruba          ABW  International tourism, number of arrivals
# 1     Afghanistan          AFG  International tourism, number of arrivals
# 2          Angola          AGO  International tourism, number of arrivals
# 3         Albania          ALB  International tourism, number of arrivals
# 4         Andorra          AND  International tourism, number of arrivals
# ..            ...          ...                                        ...
# 259        Kosovo          XKX  International tourism, number of arrivals
# 260   Yemen, Rep.          YEM  International tourism, number of arrivals
# 261  South Africa          ZAF  International tourism, number of arrivals
# 262        Zambia          ZMB  International tourism, number of arrivals
# 263      Zimbabwe          ZWE  International tourism, number of arrivals
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2011  \
# ...

# %%
#Create dataframe and format
Country_tourism = pd.DataFrame({
                            'Country':t_read['Country Name'],
                            'Country_Code':t_read['Country Code'],
                            'Indicator_Name':t_read['Indicator Name'],
                            'Indicator_Code':t_read['Indicator Code'],
                            '1995':t_read['1995'],
                            '1996':t_read['1996'],
                            '1997':t_read['1997'],
                            '1998':t_read['1998'],
                            '1999':t_read['1999'],
                            '2000':t_read['2000'],
                            '2001':t_read['2001'],
                            '2002':t_read['2002'],
                            '2003':t_read['2003'],
                            '2004':t_read['2004'],
                            '2005':t_read['2005'],
                            '2006':t_read['2006'],
                            '2007':t_read['2007'],
                            '2008':t_read['2008'],
                            '2009':t_read['2009'],
                            '2010':t_read['2010'],
                            '2011':t_read['2011'],
                            '2012':t_read['2012'],
                            '2013':t_read['2013'],
                            '2014':t_read['2014'],
                            '2015':t_read['2015'],
                            '2016':t_read['2016'],
                            '2017':t_read['2017'],
                            '2018':t_read['2018']})
Country_tourism
# Out:
#           Country Country_Code                             Indicator_Name  \
# 0           Aruba          ABW  International tourism, number of arrivals
# 1     Afghanistan          AFG  International tourism, number of arrivals
# 2          Angola          AGO  International tourism, number of arrivals
# 3         Albania          ALB  International tourism, number of arrivals
# 4         Andorra          AND  International tourism, number of arrivals
# ..            ...          ...                                        ...
# 259        Kosovo          XKX  International tourism, number of arrivals
# 260   Yemen, Rep.          YEM  International tourism, number of arrivals
# 261  South Africa          ZAF  International tourism, number of arrivals
# 262        Zambia          ZMB  International tourism, number of arrivals
# 263      Zimbabwe          ZWE  International tourism, number of arrivals
#
#     Indicator_Code       1995       1996       1997       1998       1999  \
# ...

# %%
#Merge the Two Data Frames based Country Key
country_happy_n_tourism =pd.merge(left=Country_tourism, right=Country_indicators, left_on='Country', right_on='Country')
country_happy_n_tourism
# Out:
#           Country Country_Code                             Indicator_Name  \
# 0     Afghanistan          AFG  International tourism, number of arrivals
# 1         Albania          ALB  International tourism, number of arrivals
# 2       Argentina          ARG  International tourism, number of arrivals
# 3         Armenia          ARM  International tourism, number of arrivals
# 4       Australia          AUS  International tourism, number of arrivals
# ..            ...          ...                                        ...
# 120       Vietnam          VNM  International tourism, number of arrivals
# 121       Vanuatu          VUT  International tourism, number of arrivals
# 122  South Africa          ZAF  International tourism, number of arrivals
# 123        Zambia          ZMB  International tourism, number of arrivals
# 124      Zimbabwe          ZWE  International tourism, number of arrivals
#
#     Indicator_Code       1995       1996       1997       1998       1999  \
# ...

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
#Create Engine and connection to Database
engine = create_engine('postgres://postgres:postgres@localhost:5432/ETL_Project')
conn = engine.connect()

# %%
#Check tables
engine.table_names()
# Out:
# ['country_data']

# %%
#load DataFrame into database
country.to_sql(name='country_happy_n_tourism', con=engine, if_exists='append', index=False)

# %%
#Check table in sql
pd.read_sql_query('select * from country_happy_n_tourism', con=engine).head()
# Out:
#        Country Country_Code                             Indicator_Name  \
# 0  Afghanistan          AFG  International tourism, number of arrivals
# 1      Albania          ALB  International tourism, number of arrivals
# 2    Argentina          ARG  International tourism, number of arrivals
# 3      Armenia          ARM  International tourism, number of arrivals
# 4    Australia          AUS  International tourism, number of arrivals
#
#   Indicator_Code       1995       1996       1997       1998       1999  \
# 0    ST.INT.ARVL        NaN        NaN        NaN        NaN        NaN
# 1    ST.INT.ARVL        NaN        NaN        NaN        NaN        NaN
# 2    ST.INT.ARVL  2289000.0  2614000.0  2764000.0  3012000.0  2898000.0
# 3    ST.INT.ARVL    12000.0    13000.0    23000.0    32000.0    41000.0
# 4    ST.INT.ARVL  3726000.0  4165000.0  4318000.0  4167000.0  4459000.0
#
#         2000  ...  Average_Wellbeing  Happy_Life_Years  Footprint_gha_Pcapita  \
# ...
